# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------
#
# <h2>The Sparks Foundation: Data Science & Business Analytics</h2>
#
# Submitted by: Vardan Gupta ( vardangupta00@gmail.com )
#
# Batch: July 21
#
# Task-6: Prediction using Decision Tree Algorithm(Level - Intermediate)
#
# Description: Creating Decision Tree Model on the Basis of Data inside 'Iris.csv'
#
# ------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# <h3>Importing All The Required Libraries</h3>

# %%
##Importing The Required Libraries

import pandas as pd
import matplotlib.pyplot as plt
import sklearn.datasets as datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn import tree

# %% [markdown]
# <h3>Fetching The Data From CSV File</h3>

# %% [markdown]
# <b>Reading the Data from Iris.csv</b>

# %%
#Reading the Dataset from 'Iris.csv'

dataset=datasets.load_iris()

df = df=pd.DataFrame(dataSet.data, columns=dataSet.feature_names)

# %% [markdown]
# <h3>Displaying the Data in the Dataset</h3>

# %% [markdown]
# <b>Displaying the Data in the Dataset</b>

# %%
# Displaying the Data in Dataset

df.head(200)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# <h3>Brief Analysis of Dataset</h3>

# %% [markdown]
# <b>Information about Shape of Dataset</b>

# %%
#No of Rows and Column in Dataset

print('Rows=',df.shape[0])
print('Columns=',df.shape[1])
# Out:
# Rows= 150
# Columns= 4

# %% [markdown]
# <b>Brief Analysis of Dataset</b>

# %%
#Brief Analysis of Data

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %% [markdown]
# <h3>Data Cleansing for Dataset</h3>

# %%
#Finding number of NA objects per columns

df.isna().any()
# Out:
# sepal length (cm)    False
# sepal width (cm)     False
# petal length (cm)    False
# petal width (cm)     False
# dtype: bool

# %%
#Finding number of NA objects per columns

df.isna().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# dtype: int64

# %% [markdown]
# <b>Conclusion: The Dataframe has no null or NA column</b>

# %% [markdown]
# <h3>Split the dataset in training & testing dataset</h3>

# %%
#Split the dataset in training & testing dataset using training_test_split function

x = df
y = dataset.target
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)

# %% [markdown]
# <h2>Creation of Model</h2>

# %% [markdown]
# <h3>Training of model</h3>

# %%
#Creating the Decision Tree Model

model = DecisionTreeClassifier()
model.fit(x_train,y_train)

print('Model trained successfully!')
# Out:
# Model trained successfully!

# %% [markdown]
# <h3>Testing of Model</h3>

# %% [markdown]
# <b>Define prediction variable y_prediction</b>

# %%
#Deriving the prediction variable 'y_prediction'

y_predict = model.predict(x_test)
print(y_predict)
# Out:
# [1 0 2 1 1 0 1 2 1 1 2 0 0 0 0 1 2 1 1 2 0 2 0 2 2 2 2 2 0 0 0 0 1 0 0 2 1
#  0 0 0 2 1 1 0 0 1 2 2 1 2]

# %% [markdown]
# <h3>Confusion Matrix</h3>

# %%
#Finding Error

print(confusion_matrix(y_test, y_predict))
# Out:
# [[19  0  0]
#  [ 0 15  0]
#  [ 0  0 16]]

# %%
#Finding Detailed info. about Testing 

print(metrics.classification_report(y_test,y_predict,digits=3))
# Out:
#               precision    recall  f1-score   support
#
#            0      1.000     1.000     1.000        19
#            1      1.000     1.000     1.000        15
#            2      1.000     1.000     1.000        16
#
#     accuracy                          1.000        50
#    macro avg      1.000     1.000     1.000        50
# weighted avg      1.000     1.000     1.000        50

# %% [markdown]
# <h3>Graphically Visualizing The Descision Tree Model<h3>

# %%
#Graphically Visualizing The Descision Tree Model

fn=['sepal length (cm)','sepal width (cm)','petal length (cm)','petal width (cm)']
cn=['setosa','versicolor','virginica']

fig, axes = plt.subplots(nrows = 1, ncols = 1, figsize = (4,4), dpi = 300)
tree.plot_tree(model, feature_names = fn, class_names = cn, filled = True)
plt.show()

# %% [markdown]
# <h2>Conclusion:</h2>
# <b>
#     <ol>
#         <li>I have successfully implemented the decision tree algorithm on given IRIS dataset.</li>
#         <li>Now, If we feed any new data to this classifier, it would be able to predict the right class accordingly.</li>
#     </ol>
# </b>

# %% [markdown]
# <b>------------------------------------------------------------------------------------------------Task-6 Completed-----------------------------------------------------------------------------------------</b>
