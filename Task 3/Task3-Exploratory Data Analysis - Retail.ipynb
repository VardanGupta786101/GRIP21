# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------
#
# <b>The Sparks Foundation: Data Science & Business Analytics</b>
#
# Submitted by: Vardan Gupta ( vardangupta00@gmail.com )
#
# Batch: July 21
#
# Task-3: Exploratory Data Analysis - Retail
#
# Description: To Analyse the Data of Sales of you Company Products in Different Countries, Explore the reasons, And finding the solution to inhance it.
#
# Resourses used: SampleSuperstore.csv
#
# --------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# <b>Importing The Required Libraries</b>

# %%
#Importing The Required Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <b>Fetching The Data from csv file</b>

# %%
#Reading the Dataset

df= pd.read_csv("SampleSuperstore.csv")

# %% [markdown]
# <b>Displaying the Data in the Dataset</b>

# %%
# Displaying the Data

df.head(10000)
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# <h1>Data Analysis</h1>

# %% [markdown]
# <b>Analysing Data of Top and Bottom</b>

# %%
#First five rows at Top

df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
#Last five rows at Bottom

df.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %% [markdown]
# <b>Brief Information About Dataset</b>

# %%
#No of Rows and Column in Dataset

print('Rows=',df.shape[0])
print('Columns=',df.shape[1])
# Out:
# Rows= 9994
# Columns= 13

# %%
#Brief Analysis of Data

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %% [markdown]
# <h1>Data Cleansing</h1>

# %% [markdown]
# <b>Checking for null or NA objects if any then Remove or Replaced</b>

# %%
#Finding the names of columns

df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
#Finding number of null objects per columns

df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
#Finding number of NA objects per columns

df.isna().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# <b>Briefly Checking the Data(Optional)</b>

# %%
#Finding number of null objects per columns

df.isnull().any()
# Out:
# Ship Mode       False
# Segment         False
# Country         False
# City            False
# State           False
# Postal Code     False
# Region          False
# Category        False
# Sub-Category    False
# Sales           False
# Quantity        False
# Discount        False
# Profit          False
# dtype: bool

# %%
#Finding number of NA objects per columns

df.isna().any()
# Out:
# Ship Mode       False
# Segment         False
# Country         False
# City            False
# State           False
# Postal Code     False
# Region          False
# Category        False
# Sub-Category    False
# Sales           False
# Quantity        False
# Discount        False
# Profit          False
# dtype: bool

# %%
#Finding the Distinct Data per column

df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
#Seperating certain columns
subcat_sales_profit = df.groupby(['Sub-Category'],as_index=False)[['Quantity','Sales','Discount','Profit']].sum()
print (subcat_sales_profit)
# Out:
#    Sub-Category  Quantity        Sales  Discount      Profit
# 0   Accessories      2976  167380.3180     60.80  41936.6357
# 1    Appliances      1729  107532.1610     77.60  18138.0054
# 2           Art      3000   27118.7920     59.60   6527.7870
# 3       Binders      5974  203412.7330    567.00  30221.7633
# 4     Bookcases       868  114879.9963     48.14  -3472.5560
# 5        Chairs      2356  328449.1030    105.00  26590.1663
# 6       Copiers       234  149528.0300     11.00  55617.8249
# 7     Envelopes       906   16476.4020     20.40   6964.1767
# 8     Fasteners       914    3024.2800     17.80    949.5182
# 9   Furnishings      3563   91705.1640    132.40  13059.1436
# 10       Labels      1400   12486.3120     25.00   5546.2540
# 11     Machines       440  189238.6310     35.20   3384.7569
# 12        Paper      5178   78479.2060    102.60  34053.5693
# 13       Phones      3289  330007.0540    137.40  44515.7306
# ...

# %% [markdown]
# <h1>Graphically Representing the Data</h1>

# %%
#Data based on Category

df.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %% [markdown]
# <b>Based on Category</b>

# %%
#Pairplot for category

sns.pairplot(df,hue='Category')

# %% [markdown]
# <b>Based on Region</b>

# %%
#Pairplot for Region

sns.pairplot(df,hue='Region')

# %% [markdown]
# <h1>Output</h1>

# %%
#Finding Transpose Data

df.describe().transpose()
# Out:
#               count          mean           std       min          25%  \
# Postal Code  9994.0  55190.379428  32063.693350  1040.000  23223.00000
# Sales        9994.0    229.858001    623.245101     0.444     17.28000
# Quantity     9994.0      3.789574      2.225110     1.000      2.00000
# Discount     9994.0      0.156203      0.206452     0.000      0.00000
# Profit       9994.0     28.656896    234.260108 -6599.978      1.72875
#
#                     50%        75%        max
# Postal Code  56430.5000  90008.000  99301.000
# Sales           54.4900    209.940  22638.480
# Quantity         3.0000      5.000     14.000
# Discount         0.2000      0.200      0.800
# Profit           8.6665     29.364   8399.976

# %% [markdown]
# <b>Exploratory Data Analysis</b>

# %% [markdown]
# <b>Adding new column ProfitSalesRation</b>

# %%
#Adding new columngraph named as ProfitSalesRatio

subcat_sales_profit = df.groupby(['Sub-Category'],as_index=False)[['Quantity','Sales','Discount','Profit']].sum()

#Generating Values for ProfitSalesRation
from decimal import *
def p2s(x):
    getcontext().prec=2
    val = Decimal(x['Profit'])/Decimal(x['Sales'])
    return val


#Adding The Values inside Dataset
ps=subcat_sales_profit.apply(p2s,axis=1)
ps=pd.DataFrame(data=ps,columns=['ProfitSalesRatio'])
subcat_sales_profit=pd.concat([subcat_sales_profit,ps],axis=1)

#printing subcat_sales_profitt
print (subcat_sales_profit)
# Out:
#    Sub-Category  Quantity        Sales  Discount      Profit ProfitSalesRatio
# 0   Accessories      2976  167380.3180     60.80  41936.6357             0.25
# 1    Appliances      1729  107532.1610     77.60  18138.0054             0.17
# 2           Art      3000   27118.7920     59.60   6527.7870             0.24
# 3       Binders      5974  203412.7330    567.00  30221.7633             0.15
# 4     Bookcases       868  114879.9963     48.14  -3472.5560           -0.030
# 5        Chairs      2356  328449.1030    105.00  26590.1663            0.081
# 6       Copiers       234  149528.0300     11.00  55617.8249             0.37
# 7     Envelopes       906   16476.4020     20.40   6964.1767             0.42
# 8     Fasteners       914    3024.2800     17.80    949.5182             0.31
# 9   Furnishings      3563   91705.1640    132.40  13059.1436             0.14
# 10       Labels      1400   12486.3120     25.00   5546.2540             0.44
# ...

# %% [markdown]
# <h3>Ploting Profit to Sales Ration In Bar Graph</h3>

# %%
#coding for Bar Graph

fig=plt.figure(figsize=(20,6))
plt.bar(subcat_sales_profit['Sub-Category'],subcat_sales_profit['ProfitSalesRatio'])
plt.title("Profit to Sales Ratio",fontsize=27)
plt.show()

# %% [markdown]
# <h3>ProfitSales Ratio Shows Amount Of Profit,Loss and Total Profit Per Value of Sale of Good</h3>

# %%
#Graphically Representing The Amount Of Profit,Loss and Total Profit Per Value of Sale of Good

fig2,axes= plt.subplots(3,1,figsize=(10,10),squeeze=False)
X=df['Profit']/df['Quantity']>0
X=df.loc[X,'Region']
X=X.value_counts()
Y=df['Profit']/df['Quantity']<=0
Y=df.loc[Y,'Region']
Y=Y.value_counts()
fig2.suptitle("Analysis of Profits and Loss by Region ")
sns.barplot(x= X.index,y=X,ax=axes[0][0])
sns.barplot(ax=axes[1][0],x=Y.index,y=Y)

sns.scatterplot(ax=axes[2][0],x=df['Sales']/df['Quantity'],y=(df['Profit']/df['Quantity']), data=df, hue='Region')
axes[0][0].set(xlabel="Region", ylabel="Profit Count")
axes[1][0].set(xlabel="Region", ylabel="Loss Count")
axes[2][0].set(xlabel="Sales", ylabel="Profit")
plt.legend(loc="upper right",ncol=5)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h4>We can see from above graph region with most profit and most lost as well overall profit count is much higher than loss count</h4>

# %% [markdown]
# <h3>Graphical Representation of Percentage of Orders State wise on Pie chart</h3>

# %%
#Code for Graphical Representation of Percentage of Orders State wise on Pie chart

df2=df.State.value_counts(ascending=False ,normalize=True)
df2=df2.reset_index()
df2.columns=['state','Totalorders']


fig3=plt.figure(4,figsize=(4,8))
ax=fig3.add_subplot(211)
ax.axis("equal")
pi =df2.Totalorders[:9]
left=df2.Totalorders[9:49].sum()
pi[9]=left
mylabel=['California','New York','Texas','Pennsylvania','Washington','Illinois','Ohio','Florida','Michigan','Others']
pie=ax.pie(pi,normalize=False)
ax2=fig2.add_subplot(212)
ax2.axis("off")
ax2.legend(pie[0],mylabel,loc="center",ncol=3)
ax.set_title("Percentage of Orders by State",fontsize=27)
plt.show()

# %% [markdown]
# <h3>Graphically Representing Top 15 States with Highest Overall Profit</h3>

# %%
#Graphically Representing Top 15 States with Highest Overall Profit

aggregate = df.groupby(['State'],as_index=False)[['Quantity','Sales','Discount','Profit']].sum()
aggregate=aggregate.sort_values(['Profit'], ascending = False)
aggregate=aggregate.reset_index(drop=True)

fig4=plt.figure(figsize=(20,10))
sns.barplot(x=aggregate['State'][:15],y=aggregate['Profit'][:15],data=aggregate,hue=aggregate["State"][:15],dodge=False)
plt.legend(loc="upper right",ncol=5)
plt.title("Top 15 States with Highest Overall Profit",fontsize=27)
plt.xlabel("States",fontsize=30)
plt.ylabel("Profit",fontsize=30)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h3>Graphically Representing Top 15 States with Lowest Overall Profit</h3>

# %%
#Graphically Representing Top 15 States with Lowest Overall Profit

fig5=plt.figure(figsize=(20,10))
sns.barplot(x=aggregate['State'][-15:],y=aggregate['Profit'][-15:],data=aggregate,hue=aggregate["State"][-15:],dodge=False)
plt.legend(loc="lower left",ncol=5)
plt.title("Top 15 States with Lowest Overall Profit",fontsize=30)
plt.xlabel("States",fontsize=30)
plt.ylabel("Profit",fontsize=30)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h4>
# California , New York and Washington are most profitable state while Texas, Ohio and Pennsylvania are most loss incurring State</h4>

# %% [markdown]
# <h3>Calculating and Graphically Representing Variation of Price Of Different Commodity</h3>

# %%
#Calculating Variation of Price Of Different Commodity¶

df3=df.groupby(['State','Category','Sub-Category'],as_index=False)[['Sales','Quantity','Discount','Profit']].sum()
df3=df3.sort_values(['State','Sub-Category'])
df3=df3.reset_index(drop=True)

def calprice(y):
    getcontext().prec=4
    val =(Decimal(y['Sales']) - Decimal(y['Profit']))/ Decimal(y['Quantity'])
    return val
price=df3.apply(calprice,axis=1)
price=pd.DataFrame(data=price,columns=['Price'])
df3=pd.concat([df3,price],axis=1)
df3.head(10000)
# Out:
#          State         Category Sub-Category     Sales  Quantity  Discount  \
# 0      Alabama       Technology  Accessories  2322.830        24       0.0
# 1      Alabama  Office Supplies   Appliances   208.160         1       0.0
# 2      Alabama  Office Supplies          Art   301.210        38       0.0
# 3      Alabama  Office Supplies      Binders   466.820        41       0.0
# 4      Alabama        Furniture       Chairs  3915.540        30       0.0
# ..         ...              ...          ...       ...       ...       ...
# 651  Wisconsin       Technology       Phones  4002.680        40       0.0
# 652  Wisconsin  Office Supplies      Storage  1007.160        30       0.0
# 653  Wisconsin  Office Supplies     Supplies    21.810         3       0.0
# 654  Wisconsin        Furniture       Tables   867.660         6       0.0
# 655    Wyoming        Furniture       Chairs  1603.136         4       0.2
#
#         Profit  Price
# 0     816.4346  62.75
# ...

# %%
#Graphically Representing Variation of Price Of Different Commodity¶

fig7= plt.figure(figsize=(20,10))
plt.title("Variation of Price Of Different Commodity",fontsize=27)
plt.ylabel("Price",fontsize=30)
plt.xlabel("Subcategory",fontsize=30)
sns.scatterplot(x='Sub-Category',y='Price', data=df3, hue='Sub-Category')
plt.legend(loc="upper right",ncol=5 , )
plt.show()

# %% [markdown]
# <h4>From above graph we can see that their is huge discrepency in price of same commodity across different states<br>This may be due to logistic charges assuming that price and profit margin is kept same across all the states</h4>

# %% [markdown]
# <h3> Heatmap Representing the quantity of product ordered by each state</h3>

# %%
#Calculating The Quantity of Product Ordered by each State.

states = df3['State'].unique()
subcat=df3['Sub-Category'].unique()

rows=[]
for st in states:
    idex = df3['State']==st
    idex=np.where(idex)[0]
    for sub in subcat:
        idex2=df3['Sub-Category']==sub
        idex2 = np.where(idex2)[0]
        s=np.intersect1d(idex,idex2)
        if(s.size>0):
            rows=np.append(rows,df3['Quantity'].values[s])
        else:
            rows=np.append(rows,[0])

rows = rows.reshape(49,17)

df4=pd.DataFrame(rows)
df4.columns=subcat   
df4.index=states

# %%
#Graphically Representing The Quantity of Product Ordered by each State on Heatmap

sns.set()
fig8 =plt.figure(figsize=(20,40))
sns.heatmap(df4,annot=True,fmt="g",cmap="viridis")
plt.show()

# %% [markdown]
# <h4>Above Heatmap shows the quantity of product ordered by each state , this can help us to recommend the products in demand in each state and introduce our new products accordingly.</h4>

# %%
#Displaying Profit in Descending Order (From High to Low)
df3.sort_values(['Profit'],ascending=False)
# Out:
#               State         Category Sub-Category      Sales  Quantity  \
# 426        New York       Technology     Machines  43183.500        73
# 428        New York       Technology       Phones  47502.620       393
# 418        New York  Office Supplies      Binders  32456.912       696
# 45       California       Technology  Accessories  37255.010       568
# 283        Michigan  Office Supplies      Binders  22821.970       192
# ..              ...              ...          ...        ...       ...
# 443  North Carolina       Technology     Machines  12620.655        11
# 565           Texas  Office Supplies   Appliances   2407.814       159
# 161        Illinois  Office Supplies      Binders   4538.546       327
# 464            Ohio       Technology     Machines   8978.238        39
# 567           Texas  Office Supplies      Binders   9042.676       626
#
#      Discount      Profit  Price
# 426       0.0  17320.0762  354.2
# 428       0.0  13399.1892  86.77
# ...

# %% [markdown]
# <h2>Overall Result:</h2>
# <b><ol>
# <li>Region wise west region is most profitable while it has most loss but Profit count is way more.</li>
# <li>California is most profitable state followed by New York and then washington.</li>
# <li>Texas, ohio , pensilvania are worst performing state with overall most net loss.</li>
# <li>Tables Supplies and bookcases are worst performing sub category with overall net loss.</li>
# <li>Labels , Papers and envelops are best performing sub category with overall net profit.</li>
# <li>Most loss occured in Technology and office supplies while most profit also occured in same category.It has to be noted that worst performing states performed worst in this category while its best performing in top earning statee</li></b></ol>

# %% [markdown]
# <b>-----------------------------------------------------------------------------------------------Task3 Completed----------------------------------------------------------------------------------------<b>
